# %% [markdown]
# # E_AI 01b - Python Excercises
#
#
# > 학번: 2018452067
# >
# > 이름: 정성욱

# %% [markdown]
# ## Google Colab 기본 사용법
#
# #### + Code cell
#
#   * Enter 혹은 더블 클릭 후 Python code 입력
#   * 코드 실행은 Shift + Enter 혹은 왼쪽의 플레이 버튼 클릭
#   * 코드 자동완성은 TAB
#
# #### + Text cell
#
#   * Markdown 혹은 HTML 사용
#   * 텍스트 입력 후 Shift + Enter
#
# ####

# %% [markdown]
# ## 1. Variables and data types

# %%
a = 1
b = 2
c = 3
d = True
e = 'cool'
# Out:
# False
# <class 'bool'>

# %% [markdown]
# ### Exercise #1
#
# `a == e or d and c > b` 의 결과값과 데이터 타입은?

# %%
# Answer
res = a == e or d and c > b
print(res)
print(type(res))
# Out:
# True
# <class 'bool'>

# %% [markdown]
# ### Exercise #2
#
# `not a == e or d and not c > b` 의 결과값은?

# %%
# Answer
print(not a == e or d and not c > b)
# Out:
# True

# %% [markdown]
# ## 2. Data Structures in Python

# %%
test = [ {'Arizona': 'Phoenix', 'California': 'Sacramento', 'Hawaii': 'Honolulu'},
        1000, 2000, 3000, ['hat', 't-shirt', 'jeans', {'socks1': 'red', 'socks2': 'blue'}] ]

# %% [markdown]
# ### Exercise #1:
#
# 다음 item을 출력하세요.
#
# ~~~~
# 2000
# ~~~~

# %%
# Answer
print(test[2])
# Out:
# 2000

# %% [markdown]
# ### Exercise #2:
#
# 다음 item을 출력하세요.
#
# ~~~~
# {'Arizona': 'Phoenix', 'California': 'Sacramento', 'Hawaii': 'Honolulu'}
# ~~~~

# %%
# Answer
print(test[0])
# Out:
# {'Arizona': 'Phoenix', 'California': 'Sacramento', 'Hawaii': 'Honolulu'}

# %% [markdown]
# ### Exercise #3:
#
#
# 다음 item을 출력하세요.
#
# ~~~~
# ['hat', 't-shirt', 'jeans', {'socks1': 'red', 'socks2': 'blue'}]
# ~~~~

# %%
# Answer
print(test[4])
# Out:
# ['hat', 't-shirt', 'jeans', {'socks1': 'red', 'socks2': 'blue'}]

# %% [markdown]
# ### Exercise #4:
#
# 다음 item을 출력하세요.
#
# ~~~~
# 'Phoenix'
# ~~~~

# %%
# Answer
print(test[0]['Arizona'])
# Out:
# Phoenix

# %% [markdown]
# ### Exercise #5:
#
# 다음 item을 출력하세요.
#
# ~~~~
# 'jeans'
# ~~~~

# %%
# Answer
print(test[4][2])
# Out:
# jeans

# %% [markdown]
# ### Exercise #6:
#
#
# 다음 item을 출력하세요.
#
# ~~~~
# 'blue'
# ~~~~

# %%
# Answer
print(test[4][3]['socks2'])
# Out:
# blue

# %% [markdown]
# ## 3. Functions and methods

# %%
test_yourself = [1, 1, 10, 12, 30, 2, 2, 3, 3, 3, 3, 4, 5, 5]

# %% [markdown]
# ### Exercise #1:
#
# test_yourself의 평균을 구하세요.
# (built-in 함수인 len(), sum() 만 사용)

# %%
# Answer
print(sum(test_yourself) / len(test_yourself))
# Out:
# 6.0

# %% [markdown]
# ### Exercise #2:
#
# test_yourself의 중간값을 구하세요.
# (built-in 함수인 len(), sorted() 만 사용)

# %%
# Answer
print(sorted(test_yourself)[int(len(test_yourself) / 2)])
# Out:
# 3

# %% [markdown]
# ## 4. If statements

# %% [markdown]
# ### Exercise #1:
#
# score의 점수에 따라 다음과 같은 결과를 출력하는 프로그램을 작성하세요.
# - 90~100점: A
# - 80~90점: B
# - 70~80점: C
# - 60~70점: D
# - 그 이하: F
#
# **실행 예)**
#
# ~~~~
# B
# ~~~~

# %%
score = 85

# %%
# Answer
if score >= 90:
  print('A')
elif score >= 80:
  print('B')
elif score >= 70:
  print('C')
elif score >= 60:
  print('D')
else:
  print('F')
# Out:
# B

# %% [markdown]
# ## 5. Loops

# %% [markdown]
# ### Exercise #1:
#
# scores의 모든 점수에 대해 다음과 같은 결과를 각각 출력하는 프로그램을 작성하세요.
# - 90~100점: A
# - 80~90점: B
# - 70~80점: C
# - 60~70점: D
# - 그 이하: F
#
#
# ---
#
# **실행 예)**
#
# ~~~~
# B
# F
# F
# C
# A
# ~~~~

# %%
scores = [85, 56, 34, 79, 100]

# %%
# Answer
for score in scores:
  if score >= 90:
    print('A')
  elif score >= 80:
    print('B')
  elif score >= 70:
    print('C')
  elif score >= 60:
    print('D')
  else:
    print('F')
# Out:
# B
# F
# F
# C
# A

# %% [markdown]
# ### Exercise #2:
#
# students 딕셔너리의 각 학생의 점수에 대해 다음과 아래와 같이 출력하는 프로그램을 작성하세요.
# - 90~100점: A
# - 80~90점: B
# - 70~80점: C
# - 60~70점: D
# - 그 이하: F
#
# ---
#
# **실행 예)**
#
# ~~~~
# Kim's grade: A
# Lee's grade: D
# Park's grade: C
# ~~~~

# %%
students = [{'name':'Kim', 'score':91}, {'name':'Lee', 'score':64}, {'name':'Park', 'score':78}]

# %%
# Answer
for student in students:
  score = student['score']
  if score >= 90:
    res = 'A'
  elif score >= 80:
    res = 'B'
  elif score >= 70:
    res = 'C'
  elif score >= 60:
    res = 'D'
  else:
    res = 'F'
  print("{}'s grade: {}".format(student['name'], res))
# Out:
# Kim's grade: A
# Lee's grade: D
# Park's grade: C

# %% [markdown]
# ### Exercise #3:
#
# 주어진 my_string의 값을 다음과 같은 피라미드 모양으로 출력하는 프로그램을 작성하세요.
#
# ---
#
# 실행 예)
#
# ~~~~
# p
# py
# pyt
# pyth
# pytho
# python
# pytho
# pyth
# pyt
# py
# p
# ~~~~

# %%
my_string = 'python'

# %%
# Answer
for i in range(len(my_string)+1):
  print(my_string[0:i])
for i in range(1, len(my_string)+1):
  print(my_string[0:-i])
# Out:
# p
# py
# pyt
# pyth
# pytho
# python
# pytho
# pyth
# pyt
# py
# p

# %% [markdown]
# ### Exercise #4:
#
# 사용자의 나이를 맞추는 프로그램을 작성하세요.
#
# 프로그램은 사용자에게 다음과 같은 방식으로 추측만 할 수 있고:
# - 'Are you 67 years old?'
#
# 사용자는 다음 3가지 답변만 할 수 있음:
# - less
# - more
# - yes
#
# 총 10번의 추측 안에 맞추지 못하면 종료
#
# ---
#
#
# 실행 예)
# ~~~~
# Are you 50 years old? (less/more/yes) > less
# Are you 25 years old? (less/more/yes) > less
# Are you 12 years old? (less/more/yes) > more
# Are you 18 years old? (less/more/yes) > more
# Are you 21 years old? (less/more/yes) > less
# Are you 19 years old? (less/more/yes) > yes
# Bingo!
# ~~~~

# %%
# Answer


prediction = step = 50
for _ in range(10):
  res = input("Are you {} years old? (less/more/yes) > ".format(prediction))
  if res == 'yes':
    print('Bingo!')
    break
  elif res == 'less':
    step = step / 2
    prediction = int(prediction - step)
  elif res == 'more':
    step = step / 2
    prediction = int(prediction + step)
# Out:
# Are you 50 years old? (less/more/yes) > less
# Are you 25 years old? (less/more/yes) > less
# Are you 12 years old? (less/more/yes) > less
# Are you 5 years old? (less/more/yes) > more
# Are you 8 years old? (less/more/yes) > more
# Are you 9 years old? (less/more/yes) > more
# Are you 9 years old? (less/more/yes) > more
# Are you 9 years old? (less/more/yes) > more
# Are you 9 years old? (less/more/yes) > less
# Are you 8 years old? (less/more/yes) > more

# %% [markdown]
# ### Exercise #5:
#
#
# ![](http://kfem.or.kr/wp-content/uploads/2018/12/AQI.png)
#
#
# 주어진 테이블을 토대로 각각의 등급을 반환하는 다음 함수를 작성하세요:
#
# - **get_aqi_pm10()**
# - **get_aqi_pm25()**
#
#
# 등급은 다음과 같이 int로 반환
# (테이블 범위를 초과하는 값은 5로 반환)
#
#
# - 1 - Good
# - 2 - Moderate
# - 3 - Unhealty for Sensitive Groups
# - 4 - Unhealty
# - 5 - Very Unhealty
#
# ---
#
# **실행 예)**
# ~~~~
# 1
# 2
# 5
# 2
#
# 1
# 2
# 3
# 5
# ~~~~

# %%
# Answer

def get_aqi_pm10(value):
  if value >= 355:
    res = 5
  elif value >= 255:
    res = 4
  elif value >= 155:
    res = 3
  elif value >= 55:
    res = 2
  elif value >= 0:
    res = 1
    
  return res # edit this

# %%
# Answer

def get_aqi_pm25(value):
  if value >= 151:
    res = 5
  elif value >= 56:
    res = 4
  elif value >= 36:
    res = 3
  elif value >= 12:
    res = 2
  elif value >= 0:
    res = 1
    
  return res # edit this

# %%
print( get_aqi_pm10(50) )
print( get_aqi_pm10(100) )
print( get_aqi_pm10(400) )
print( get_aqi_pm10(55), end='\n\n' )

print( get_aqi_pm25(3) )
print( get_aqi_pm25(12) )
print( get_aqi_pm25(55) )
print( get_aqi_pm25(300) )
# Out:
# 1
# 2
# 5
# 2
#
# 1
# 2
# 3
# 5

# %% [markdown]
# ### Exercise #6:
#
# 현재 pm2.5, pm10 수치를 가져오는 **get_pm()** 함수와
#
# Exercise #5에서 완성한 **get_aqi_pm25()**, **get_aqi_pm10()**을 이용하여
#
# 현재 대기 지수 AQI를 다음과 같이 출력하는 프로그램을 완성하세요.
#
# AQI는 pm 2.5와 pm 10 중에서 더 안좋은 결과를 출력하도록 함
#
# ---
#
# **실행 예)**
#
#
# ~~~~
# pm 2.5 = 72, pm 10 = 109
# 현재 대기지수 AQI는: Unhealty 입니다.
# ~~~~

# %%
from bs4 import BeautifulSoup
import urllib.request as req

def get_pm():

    url1 = 'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&query=%EC%A0%84%EA%B5%AD%EC%B4%88%EB%AF%B8%EC%84%B8%EB%A8%BC%EC%A7%80'
    selector1 = '#main_pack > div.content_search.section._atmospheric_environment > div > div.contents03_sub > div > div:nth-of-type(3) > div.main_box > div.detail_box > div.tb_scroll > table > tbody > tr:nth-of-type(1) > td:nth-of-type(1) > span'

    url2 = 'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&query=%EC%A0%84%EA%B5%AD%EB%AF%B8%EC%84%B8%EB%A8%BC%EC%A7%80'
    selector2 = '#main_pack > div.content_search.section._atmospheric_environment > div > div.contents03_sub > div > div:nth-of-type(3) > div.main_box > div.detail_box > div.tb_scroll > table > tbody > tr:nth-of-type(1) > td:nth-of-type(1) > span'

    # pm 2.5
    res = req.urlopen(url1)
    soup = BeautifulSoup(res, 'html.parser')
    elem = soup.select_one(selector1)
    pm25 = int(elem.text)
    
    
    # pm 10
    res = req.urlopen(url2)
    soup = BeautifulSoup(res, 'html.parser')
    elem = soup.select_one(selector2)
    pm10 = int(elem.text)

    return (pm25, pm10)

# %%
# Answer

aqi_label = {1:'Good', 2:'Moderate', 3:'Unhealty for Sensitive Group', 4:'Unhealty', 5:'Very Unhealty'}

pm25, pm10 = get_pm()

print(pm25, pm10)

index25 = get_aqi_pm25( pm25 )
index10 = get_aqi_pm10( pm10 )


# do something
aqi_index = index25
if index10 > index25:
  aqi_index = index10


print('pm 2.5 = {}, pm 10 = {}'.format(pm25, pm10) )
print('현재 대기지수 AQI는: {} 입니다.'.format(aqi_label[aqi_index])) # edit this
# Out:
# 15 34
# pm 2.5 = 15, pm 10 = 34
# 현재 대기지수 AQI는: Moderate 입니다.
